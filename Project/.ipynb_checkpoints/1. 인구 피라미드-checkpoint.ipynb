# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ## 남자 데이터 정의

# %%
import pandas as pd
file_name = '201208.xlsx'
df_male = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,E:Y')
df_male.head(3)
# Out:
# C:\Users\MS\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,198,133  1,207,817  1,579,012  1,861,218  1,726,993  1,737,287
# 서울특별시      216,098    209,970    272,464    337,848    342,836    407,191
# 부산광역시       67,995     68,543     96,038    125,646    125,403    120,754
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       2,081,363  2,102,836  2,359,969  2,161,513  ...  1,647,929
# 서울특별시      479,466    439,202    466,095    408,648  ...    337,525
# 부산광역시      139,826    131,442    148,136    142,687  ...    139,294
#
#             60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세 95~99세  \
# 행정기관
# ...

# %%
df_male.iloc[0] = df_male.iloc[0].str.replace(',', '').astype(int) # '1,198,133' -> '1198133' -> 1198133

# %%
df_male
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1198133  1207817  1579012  1861218  1726993  1737287  2081363
# 서울특별시      216,098  209,970  272,464  337,848  342,836  407,191  479,466
# 부산광역시       67,995   68,543   96,038  125,646  125,403  120,754  139,826
# 대구광역시       53,754   58,128   82,458  101,569   95,569   82,275   92,421
# 인천광역시       69,305   68,031   87,518  106,910  101,482   99,069  120,399
# 광주광역시       37,197   40,446   55,129   62,374   52,456   49,803   58,976
# 대전광역시       38,517   39,918   51,758   60,793   56,072   53,658   62,066
# 울산광역시       29,847   29,160   39,622   49,232   43,601   39,396   48,650
# 세종특별자치시      2,725    2,658    3,133    3,229    3,225    3,369    4,290
# 경기도        320,603  324,398  403,796  452,645  399,893  400,746  507,092
# 강원도         32,081   35,351   47,670   54,547   53,380   46,699   51,524
# 충청북도        37,672   37,849   49,884   58,077   52,614   51,873   58,774
# ...

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_female = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,AB:AV')
df_female.head(3)
# Out:
# C:\Users\MS\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       1,129,024  1,124,211  1,445,201  1,652,850  1,549,240  1,630,296
# 서울특별시      204,443    197,706    251,723    305,575    337,683    415,280
# 부산광역시       64,550     63,573     86,132    107,485    110,547    113,978
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,996,904  2,025,807  2,271,586  2,060,121  ...  1,659,145
# 서울특별시      471,426    426,838    459,881    408,451  ...    364,878
# 부산광역시      133,861    127,188    149,774    147,233  ...    146,120
#
#           60~64세.1   65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# ...

# %%
df_male.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_female.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_female.columns = df_male.columns # columns 통일
df_female.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_female.iloc[0] = df_female.iloc[0].str.replace(',', '').astype(int) # '1,198,133' -> '1198133' -> 1198133

# %%
df_female
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1129024  1124211  1445201  1652850  1549240  1630296  1996904
# 서울특별시      204,443  197,706  251,723  305,575  337,683  415,280  471,426
# 부산광역시       64,550   63,573   86,132  107,485  110,547  113,978  133,861
# 대구광역시       50,080   52,950   72,454   85,597   75,417   74,707   93,054
# 인천광역시       65,719   64,027   81,027   96,889   94,123   93,860  114,325
# 광주광역시       34,829   37,173   50,935   57,009   48,365   48,380   59,181
# 대전광역시       35,992   37,512   47,254   53,819   49,522   50,748   62,078
# 울산광역시       27,738   26,249   35,074   40,924   34,251   34,173   44,884
# 세종특별자치시      2,721    2,626    2,948    2,754    2,810    2,742    3,776
# 경기도        303,255  304,886  374,431  409,756  372,524  380,348  496,090
# 강원도         30,232   32,390   43,455   48,620   42,594   38,445   48,395
# 충청북도        35,502   35,084   45,918   51,159   44,291   45,131   54,681
# ...

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_male.columns, -df_male.iloc[0] // 1000) # 단위 : 천 명
plt.barh(df_female.columns, df_female.iloc[0] // 1000)

title='2012 대한민국 인구 피라미드'
save='2012_인구피라미드'
plt.title(title)
plt.savefig(save, dpi=100)
plt.show()
